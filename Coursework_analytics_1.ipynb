# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakakakilig/DS_coursework/blob/main/Coursework_analytics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
#
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime as dt

# %%
# Запишем данные из csv файлов в датафреймы и проведём предварительную обработку(переименуем столбцы, выбросим лишнее)

# Курсы
# Столбец id переименовываем в course_id для однозначности при дальлнейшем объединении датафреймов.
Courses = pd.read_csv('courses.csv') \
    .rename(columns={'id': 'course_id'}) \
    .drop(['Unnamed: 0'], axis=1)

# Студенты
Students = pd.read_csv('students.csv',parse_dates=[-1])

# Содержание курсов
Course_contents = pd.read_csv('course_contents.csv')

# Прогресс
# Переименовываем столбец id в progress_id
Progresses = pd.read_csv('progresses.csv') \
    .rename(columns={'id': 'progress_id'})

Progress_phases = pd.read_csv('progress_phases.csv')

# %%
# Перед тем как объединять датафреймы в сводные для последующей работы - посмотрим информацию по ним.
# 1. выведем информацию об отсутствующих данных по всем датафреймам.
print(Courses.isna().sum(), '\n')
print(Students.isna().sum(), '\n')
print(Course_contents.isna().sum(), '\n')
print(Progresses.isna().sum(), '\n')
print(Progress_phases.isna().sum(), '\n')

# Видим, что отсутствующие данные есть всего в двух датафреймах. 
# Нет данных о городах и днях рождения большого количества студентов.
# Также есть пропущенные данные в столбце finish_date датафрейма progress_phases.
# Вероятно это незаконченные домашние работы, курсовые и т.д.
# В целом данные достаточно полные. Это обнадёживает.
# Out:
# course_id    0
# title        0
# field        0
# dtype: int64
#
# id_             0
# id              0
# city        30668
# birthday    18331
# dtype: int64
#
# course_id        0
# module_number    0
# module_title     0
# lesson_number    0
# lesson_title     0
# lesson_token     0
# is_video         0
# is_homework      0
# dtype: int64
#
# progress_id    0
# student_id     0
# course_id      0
# dtype: int64
#
# progress_id          0
# module_number        0
# lesson_number        0
# status               0
# start_date           0
# finish_date      16169
# dtype: int64

# %%
#объединяем таблицы, связаны с курсом, по общему идентификатору
cors = pd.merge(Courses, Course_contents, on = 'course_id')
#объединяем таблицы, связаны с прогрессом, по общему идентификатору
prog = pd.merge(Progresses,Progress_phases, on = 'progress_id')

#объединяем все таблицы, кроме "students.csv", по общим идентификаторам
main = pd.merge(cors, prog, on = ['course_id','module_number','lesson_number'])
main.head()
# Out:
#                           course_id  ...                    finish_date
# 0  943306102e5b067d08a29094f37b8193  ...  2019-04-13 17:32:19.134874+00
# 1  943306102e5b067d08a29094f37b8193  ...  2019-06-13 19:51:21.987534+00
# 2  943306102e5b067d08a29094f37b8193  ...  2019-03-27 06:56:54.834751+00
# 3  943306102e5b067d08a29094f37b8193  ...  2019-05-29 06:47:21.794092+00
# 4  943306102e5b067d08a29094f37b8193  ...  2019-03-24 09:50:32.595199+00
#
# [5 rows x 15 columns]

# %% [markdown]
# #  1.

# %%
# Общее количество курсов в датасете
print(len(pd.unique(main['title'])));
# Out:
# 15

# %%
# Количество модулей на каждом курсе
print('Количество модулей на каждом курсе')
main.groupby('title').nunique().module_title.sort_values(ascending=False)
# Out:
# Количество модулей на каждом курсе
# title
# Анимация интерфейсов                   21
# Веб-разработчик                        20
# UX-дизайн                              20
# Веб-дизайн с нуля 2.0                  19
# Интернет-маркетолог от Ingate          18
# JavaScript с нуля                      18
# Руководитель digital-проектов          17
# Веб-дизайн Базовый                     17
# Веб-дизайн PRO 2.0                     17
# Java-разработчик                       17
# SMM-маркетолог от А до Я               11
# Java-разработчик c нуля                 9
# Excel Базовый                           9
# Веб-вёрстка для начинающих 2.0          8
# PHP-разработчик с 0 до PRO. Часть 1     8
# Name: module_title, dtype: int64

# %%
# Количество уроков в каждом модуле на каждом курсе
les_by_mod_by_course = main.groupby(['title','module_number'])['lesson_title'].nunique().unstack(level=0)
les_by_mod_by_course
# Out:
# title          Excel Базовый  ...  Руководитель digital-проектов
# module_number                 ...
# 1                       11.0  ...                            4.0
# 2                        7.0  ...                            3.0
# 3                        3.0  ...                            4.0
# 4                        7.0  ...                            3.0
# 5                        5.0  ...                            4.0
# 6                        5.0  ...                            5.0
# 7                        5.0  ...                            6.0
# 8                        5.0  ...                           12.0
# 9                        1.0  ...                            4.0
# 10                       NaN  ...                            5.0
# 11                       NaN  ...                            6.0
# 12                       NaN  ...                            5.0
# 13                       NaN  ...                            4.0
# ...

# %%
# Медианное количество уроков в модуле на каждом курсе
# Просто применяю к предыдущему датафрейму функцию median по столбцам.
les_by_mod_by_course.apply('median',axis=0)
# Out:
# title
# Excel Базовый                           5.0
# Java-разработчик                        7.0
# Java-разработчик c нуля                10.0
# JavaScript с нуля                       7.0
# PHP-разработчик с 0 до PRO. Часть 1     4.0
# SMM-маркетолог от А до Я                6.0
# UX-дизайн                               3.5
# Анимация интерфейсов                    3.0
# Веб-вёрстка для начинающих 2.0          7.0
# Веб-дизайн PRO 2.0                      5.0
# Веб-дизайн Базовый                      3.0
# Веб-дизайн с нуля 2.0                   4.0
# Веб-разработчик                         2.0
# Интернет-маркетолог от Ingate           6.5
# Руководитель digital-проектов           5.0
# dtype: float64

# %%
# Количество учеников на каждом курсе
students_count_by_course = main.groupby('title').nunique().student_id.sort_values(ascending=False)
students_count_by_course
# Out:
# title
# Интернет-маркетолог от Ingate          2168
# Веб-дизайн с нуля 2.0                  2014
# Веб-вёрстка для начинающих 2.0         2004
# Веб-дизайн PRO 2.0                     1711
# UX-дизайн                              1151
# JavaScript с нуля                       966
# PHP-разработчик с 0 до PRO. Часть 1     854
# Excel Базовый                           782
# Java-разработчик                        763
# Руководитель digital-проектов           685
# Веб-разработчик                         628
# Анимация интерфейсов                    598
# Java-разработчик c нуля                 581
# Веб-дизайн Базовый                      518
# SMM-маркетолог от А до Я                506
# Name: student_id, dtype: int64

# %%
# Минимальный, максимальный, средний и медианный возраст студентов.
# Предполагаю, что данные нам нужны только из общего датасета.
# Возраст считаем на последнюю дату по столбцам start_date и finish_date. Считать возраст на текущий день некорректно.
# tz_localize(None) убирает данные о таймзоне. Они не сильно нужны, но мешают расчёту возраста, поскольку дни рождения
# в датафрейме указаны без таймзоны.

#cоздаем копию датафрейма
age_ = Students.copy()

#удаляем ненужныем столбцы
age_.drop(['id_' , 'city'], axis=1, inplace=True)

#соеденяем 2 датафрейма по id, которые имеют разные название в разных датафреймах
age_ = pd.merge(age_, main, left_on = 'id', right_on = 'student_id')

#оставляем только нужные столбцы
age = age_[['id','birthday','start_date']]

#переводим строку в дату
age['start_date'] = pd.to_datetime(age.start_date).dt.tz_localize(None)
age['birthday'] = pd.to_datetime(age.birthday, errors='coerce').dt.tz_localize(None)

#находим разницу между датой рождения и первым выполненным заданием  в годах
age['Years'] = (age.start_date - age.birthday).astype('timedelta64[Y]')

#берем только те даты, которые +- похожи на реальные
age = age.loc[(age.birthday >='1950/1/1') & (age.birthday <='2003/12/31'), :]
age.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Минимальный, максимальный, средний, медианный возраст студентов
print(f'Минимальный возраст   {(age.Years.min())}\
       \nМаксимальный          {(age.Years.max())}\
       \nСредний               {round((age.Years.mean()),2)}\
       \nМедианный             {(age.Years.median())}')
# Out:
# Минимальный возраст   14.0
# Максимальный          65.0
# Средний               28.27
# Медианный             27.0

# %%
age1 = pd.merge(age,Progresses, left_on='id',right_on='student_id')
age1
Progresses
age2 = pd.merge(age1,Courses, on='course_id')
age2
# Out:
#                                       id  ...        field
# 0       35a36d90b745992b59085c8d54a072e7  ...  Development
# 1       35a36d90b745992b59085c8d54a072e7  ...  Development
# 2       35a36d90b745992b59085c8d54a072e7  ...  Development
# 3       a59b13ce713813676ef3815673929254  ...  Development
# 4       a59b13ce713813676ef3815673929254  ...  Development
# ...                                  ...  ...          ...
# 692846  3cc3e4260104b427d9c9b2b9305f0117  ...    Marketing
# 692847  3cc3e4260104b427d9c9b2b9305f0117  ...    Marketing
# 692848  3cc3e4260104b427d9c9b2b9305f0117  ...    Marketing
# 692849  3cc3e4260104b427d9c9b2b9305f0117  ...    Marketing
# 692850  3cc3e4260104b427d9c9b2b9305f0117  ...    Marketing
#
# [692851 rows x 9 columns]

# %%
# Данные о возрасте студентов по каждому из курсов
# Группируем по курсам и сразу считаем все 4 величины
ages_by_course = age2.groupby('title').agg({'Years':['max','min','mean','median']})
# Убираем иерархический индекс у столбцов.
ages_by_course.columns = ages_by_course.columns.droplevel(0)
# Добавляем префикс age к именам столбцов, для лучшей читаемости.
ages_by_course.rename(columns={'max':'age_max', 'min':'age_min', 'mean':'age_mean', 'median':'age_median'}, inplace=True)
print('Данные о возрасте студентов по каждому курсу:')
ages_by_course.sort_values(by='age_median', ascending=False)
# Out:
# Данные о возрасте студентов по каждому курсу:
#                                      age_max  age_min   age_mean  age_median
# title
# Excel Базовый                           59.0     15.0  31.493106        31.0
# Интернет-маркетолог от Ingate           59.0     15.0  29.852517        29.0
# Руководитель digital-проектов           54.0     17.0  30.097218        29.0
# Java-разработчик c нуля                 54.0     15.0  28.905560        28.0
# UX-дизайн                               56.0     14.0  28.411393        28.0
# Java-разработчик                        63.0     15.0  28.531854        27.0
# SMM-маркетолог от А до Я                51.0     16.0  27.994832        27.0
# Анимация интерфейсов                    50.0     14.0  28.160491        27.0
# JavaScript с нуля                       58.0     14.0  26.988993        26.0
# PHP-разработчик с 0 до PRO. Часть 1     65.0     14.0  27.309104        26.0
# ...

# %%
plt.figure(figsize=(10,5))
ax = plt.bar(students_count_by_course.index, students_count_by_course)
# Подписи столбцов поворачиваем, выравниваем по правому краю и привязываем к столбцу 
plt.title('Количество студентов по курсам', fontsize=10)
plt.xticks(rotation=30, ha='right', fontsize=10)
# plt.yticks(fontsize=10)
plt.ylabel(ylabel='Количество студентов', fontsize=12)
plt.show()

# %%
# Отдельно для этого графика создаём датафрейм с дополнительной колонкой field и сразу отсортируем по убыванию.
df1_3 = main.groupby('title').agg({'student_id':'nunique', 'field':'first'}).\
                sort_values(by='student_id', ascending=False)

# Создадим словарь цветов для каждой сферы.Он нам пригодится для легенды.
# Можно и вручную было цвета прописать, но через формирование цветовой палитры можно свободно менять их.
mapper = sns.color_palette('deep',df1_3.field.unique().size)
color_dict = {}
for num, field in enumerate(df1_3.field.unique()):
    color_dict[field] = mapper[num]

# А теперь сформируем палитру для графика:
my_palette = []
for element in df1_3.field:
    my_palette.append(color_dict[element])

plt.figure(figsize=(20,10))
# По-поводу альфы не совсем понятно в задании. Альфа 0.9 означает прозрачность 0.1 и наоборот соответственно.
# При альфе 0.1 почти ничего не будет видно, поэтому я предположил, что имелась в виду альфа 0.9
students_hbar = sns.barplot(x='student_id', y=df1_3.index, data=df1_3, palette=my_palette, alpha=0.9)

# Отрисуем вертикальную линию по медианному количеству студентов.
fl = plt.axvline(df1_3.student_id.median(), ls='--', lw=3, color='purple', alpha=0.9, label='Медианное количество студентов')
# Добавим для неё отдельный xtick
xt = students_hbar.get_xticks() 
xt = np.append(xt,df1_3.student_id.median())
students_hbar.set_xticks(xt)

# И отдельную легенду для этой линии.
first_legend = plt.legend(handles=[fl], loc=7, fontsize = 20, shadow=True)
# Теперь добавим эту легенду в текущий axes
plt.gca().add_artist(first_legend)

# Нарисуем вручную прямоугольники для легенды и присвоим им цвета из нашего словаря цветов.
handles = [plt.Rectangle((0,0),1,1, color=color_dict[key], alpha=.9) for key in color_dict.keys()]
# Отрисовываем вторую легенду.
plt.legend(handles, color_dict.keys(), fontsize=20, title='Field', title_fontsize=25, shadow=True)

# Настроим подписи графика, осей, меток.
plt.title('Количество студентов по курсам', fontsize=25)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlabel('Количество студентов', fontsize=20)
plt.ylabel(None)

# Убираем рамку и отрисовываем вертикальные линии сетки, для лучшей читаемости диаграммы.
plt.box(False)
plt.grid(axis='x', alpha=0.3, ls='--', lw=2)
plt.show()

# %% [markdown]
# 1.   В csv файле с данными о студентах информация о дне рождения отсутствует у 41.84% студентов. Также есть 9 студентов с датами рождения не соответствующими формату даты. И еще больше тысячи студентов, у которых возраст откровенно некорректный.
#  **Предложение: Возможно есть смысл сделать поле "дата рождения" обязательным для заполнения при регистрации. Если же это невозможно, то стоит хотя бы сделать указание даты рождения в виде выбора дня, месяца, года. Как выпадающие меню или отдельными полями, в которых можно будет вводить только корректные даты. Это позволит избавиться от дат вида 0001-05-28 и т.д.**
# 2.   Всего курсов в датасете 15. Наибольшее количество модулей у курсов **"Анимация интерфейсов", "Веб-разработчик"** и **"UX-дизайн"**. Наименьшее - у курсов **"Excel Базовый", "Веб-вёрстка для начинающих 2.0", "PHP-разработчик с 0 до PRO. Часть 1"**.
# При этом медианным количеством уроков в модуле ярко выделяется курс "Java-разработчик c нуля".
# 3. Если рассматривать количество уроков по модулям на каждом курсе в целом картина примерно похожая у все. В первых модулях количество уроков несколько больше. Видимо из-за вводных моментов и общей информации. Затем количество уроков в модуле снижается и остаётся примерно равным до самого последнего. Но есть несколько отличающихся курсов.
# На курсе "Java-разработчик c нуля" количество уроков после первых модулей наоборот становится больше, а к 4 модулю доходит до 27. Это второй по величине показатель после курса "Интернет-маркетолог от Ingate", у которого в 16 модуле целых 29 уроков.
#  **Предложение: Количество уроков в этих курсах очень неравномерно распределено, это может привести к резкому увеличению времени прохождения одного модуля. Может быть даже снизит мотивацию студентов. Вероятно есть смысл попробовать разбить эти модули на 2 или 3, сделав таким образом нагрузку более равномерной.**

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# ### 2.1. (p) Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.

# %%
# first_module = Course_contents[Course_contents['is_homework']==True].groupby(['course_id']).module_number.min()
# first_hw = pd.merge(first_module,main, on='course_id')
# first_hw['start_date']=pd.to_datetime(first_hw.start_date).dt.tz_localize(None)
# first_hw['start_date']=first_hw.start_date.apply(lambda x: x.strftime('%Y-%m'))

# first_hw.rename(columns={'module_number_x': 'module_first_hw','module_number_y':'module_number'},inplace=True)
# first_hw = first_hw[first_hw.module_first_hw==first_hw.module_number]
# first_hw = first_hw[['module_first_hw','title','student_id','start_date']]

# first_hw = first_hw.groupby(['start_date','title']).student_id.nunique().reset_index()
# first_hw = first_hw.pivot(index = 'start_date', columns='title', values = 'student_id').fillna(0)

# first_hw

# %%
# В этом и последующих блоках при формировании датафрейма для работы названия им даю по номеру блока.

# Сначала сделал такой вариант, группировка, реформат и две сортировки работают достаточно быстро.
# 1. Выбираем только те строки которые относятся к домашним работам. Группируем по курсу и по айди студента,
# выбираем самую раннюю дату начала домашней работы и сбрасываем индекс. 
df2_1 = main[main['is_homework'] == True].groupby(['title', 'student_id']).start_date.min().reset_index()
# 2. Создаем столбец с отформатированными датами. Нам нужен только месяц и год.
df2_1['year_month'] = pd.to_datetime(df2_1.start_date).apply(lambda x: x.strftime('%Y-%m'))
# 3. Группируем по курсу и дате и считаем количество студентов. Unstack здесь нужен для того, чтобы курсов была
# одинаковая шкала дат.
df2_1 = df2_1.groupby(['title','year_month']).student_id.count().unstack(level=0).fillna(0)
# Здесь всё работает достаточно хорошо, но я понял, что такой вариант не совсем правильный. Студент может начать выполнять
# домашние работы в модуле не по порядку. Поэтому я собрал датафрейм по-другому.


# 1. Собираем датафрейм с номерами в которых впервые появляется домашнее задание в модуле. 
# Сначала отфильтровываем только те строки, которые относятся к домашним работам.
# затем группируем по курсам и модулям и выбираем уроки с минимальным номером. Сбрасываем индекс.
# снова группируем уже только по курсам и выбираем первые строки. В итоге получаем список номеров модулей и уроков,
# где впервые появляется домашняя работа.
first_lessons = main.loc[main['is_homework'] == True].groupby(['title','module_number']).agg({'lesson_number':'min'})\
                .reset_index().groupby('title').first().reset_index()
# 2. Теперь с помощью merge способом left из основного датафрейма оставим только нужные нам строки.
df2_1_best = first_lessons.merge(main[main['is_homework'] == True],\
                                 on=['title','module_number','lesson_number'], how='left')

# 3. Создаем столбец с отформатированными датами. Нам нужен только месяц и год.
df2_1_best['year_month']=pd.to_datetime(df2_1_best.start_date).apply(lambda x: x.strftime('%Y-%m'))
# 4. Также группируем по курсу и дате и считаем количчество студентов. Опять же unstack здесь нужен в основном для того,
# чтобы для всех курсов была одинаковая временная шкала.
df2_1_best = df2_1_best.groupby(['title','year_month']).student_id.nunique().unstack(level=0).fillna(0)

# Вот так выглядит итоговый датафрейм.
df2_1_best
# Out:
# title       Excel Базовый  ...  Руководитель digital-проектов
# year_month                 ...
# 2016-03               0.0  ...                            0.0
# 2016-11               0.0  ...                            0.0
# 2017-03               0.0  ...                            0.0
# 2017-04               0.0  ...                            0.0
# 2017-05               0.0  ...                            1.0
# 2017-06               0.0  ...                            1.0
# 2017-07               0.0  ...                            0.0
# 2018-01               0.0  ...                            0.0
# 2018-02               6.0  ...                           64.0
# 2018-03               3.0  ...                           42.0
# 2018-04               0.0  ...                           32.0
# 2018-05               3.0  ...                           27.0
# 2018-06               9.0  ...                           36.0
# 2018-07              13.0  ...                           30.0
# ...

# %% [markdown]
# ### 2.2. (m) На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.

# %%
# Создаем список столбцов(курсы), по которому будем итерироваться.
titles_list = df2_1.columns

# Выставим единую шкалу прироста студентов для всех графиков.
# Так лучше видно относительное изменение прироста.
fig,ax = plt.subplots(5,3, figsize=(20,30), sharey=True)
counter = 0
for i in range(5):
    for j in range(3):
        ax[i,j].plot(df2_1_best.index, df2_1_best[titles_list[counter]], lw=2, color='red')
# Устанавливаем название для каждого графика по названию курса.
        ax[i,j].set_title(titles_list[counter], fontsize=18)
# Устанавливаем подписи для осей.
# Чтобы не захламлять графики оставил подписи оси y только у крайних левых графиков.
        ax[i,0].set_ylabel('Прирост студентов', fontsize=15)
# Мне кажется, что здесь подпись оси х не особо нужна. И так понятно, что это даты. 
# Я эту строку оставил, но закомментировал.
#         ax[i,j].set_xlabel('Даты', fontsize=15)

# Настраиваем шкалу оси х (даты). Всего месяцев 26, достаточно много для таких небольших графиков, поэтому
# брал каждое второе значение. Выровнял по правому краю и повернул на 30 градусов относительно точки привязки.
        ax[i,j].set_xticks(df2_1_best.index[::2])
        ax[i,j].set_xticklabels(df2_1_best.index[::2], rotation=30, rotation_mode='anchor', ha='right', fontsize=12)
        counter += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3. (m) На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐

# %%
# first_hw.plot(subplots=False, figsize = (12,8), rot=45)
# plt.title('График прироста студентов по месяцам', fontsize=20)
# plt.ylabel('Прирост', fontsize=16)
# plt.xlabel('Месяц', fontsize=16)
# plt.legend()
# for spine in plt.gca().spines.values():
#     spine.set_visible(False)
# plt.show()

# %%
# Общий график на все 15 курсов

plt.figure(figsize=(20,15))
count = 0
for i in range(5):
    for j in range(3):
# В цикле рисуем графики, сразу назначая label, толщину линии и цвет из палитры
        plt.plot(df2_1_best.index, df2_1_best[titles_list[count]], label=titles_list[count],\
                 lw=2)
        count += 1
plt.title('Распределение прироста студентов на курсе по месяцам', fontsize=20)
# Отрисовываем легенду.        
leg = plt.legend(fontsize=15)
# Линии слишком тонкие в базе, поэтому увеличиваю их толщину в цикле, так лучше читается.
[line.set_linewidth(4) for line in leg.get_lines()]
# Настраиваем ось x, на сводном графике умещаются все 26 месяцев, поэтому прореживать их тут не нужно.
plt.xticks(df2_1.index, rotation=20, ha='center', rotation_mode='anchor', fontsize=12)
# Настраиваем подписи осей и размер шрифта.
plt.yticks(fontsize=14)
plt.ylabel('Прирост студентов', fontsize=15)
# Для лучшей читаемости отрисовываем сетку.
plt.grid(axis='both', alpha=0.2, ls='--', lw=1)
# Убираем рамку у графика.
plt.box(False)
plt.show()

# %% [markdown]
# ## 2.4. (p) Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
# 3.1
# Сначала почистим датафрейм. Оставим только домашние задания и отбросим те записи,
# где дата начала домашнего задания больше чем дата его окончания. На такие записи потом посмотрим отдельно.
# Чтобы код не загромождать запишем условие фильтрации отдельно.
clause = (main['start_date'] < main['finish_date']) & (main['is_homework']==True)
# Отбросим записи с отсутствующими значениями в столбцах с датами начала и завершения домашней работы.
df3_1 = main[clause].dropna(subset=['start_date', 'finish_date'])
# Для каждого студента определим самую раннуюю дату начала домашней работы и самую позднюю дату завершения
df3_1 = df3_1.groupby(['title','module_number', 'module_title','student_id'])\
                        .agg({'start_date':'min', 'finish_date':'max'}).reset_index()
# Создадим столбец с временем выполнения домашней работы
df3_1.finish_date = pd.to_datetime(df3_1.finish_date).dt.tz_localize(None)
df3_1.start_date = pd.to_datetime(df3_1.start_date).dt.tz_localize(None)
df3_1['homework_time'] = df3_1['finish_date'] - df3_1['start_date']
# Сгруппируем датафрейм по курсам, названию и номеру модуля и сразу посчитаем сразу max,min,mean и median
# Тут есть небольшая особенность. Дело в том что функция mean() и median() в python 
# может работать и для объектов типа timedelta. Но в pandas groupby.agg() реализован на python так, что 
# mean и median работают только с numeric типом данных. Я в данном случае преобразовал timedelta к int64,
# потом посчитал все нужные параметры и преобразовал обратно к timedelta.
df3_1['homework_time'] = df3_1['homework_time'].astype('int64')
df3_1 = df3_1.groupby(['title','module_number','module_title'])\
                        .agg({'homework_time':['min','max','median']}).astype('timedelta64[ns]')
# Сбрасываем мультииндекс у столбцов и уровень module_title у строк
df3_1 = df3_1.droplevel(0,axis='columns').reset_index(level=2)
df3_1.head(15)
# Out:
#                                                                      module_title  ...           median
# title            module_number                                                     ...
# Excel Базовый    1                                      Основной функционал Excel  ...  3 days 00:00:00
#                  2                        Основной функционал Excel (продолжение)  ...  2 days 00:00:00
#                  3                              Формулы и функции Excel. Введение  ...  2 days 00:00:00
#                  4              Формулы и функции Excel. Продолжаем работать с...  ...  4 days 00:00:00
#                  5                 Формулы и функции Excel. Более сложные формулы  ...  3 days 00:00:00
#                  6              Формулы и функции Excel. Работа с ошибками, пр...  ...  3 days 00:00:00
#                  7                                      Визуализация данных Excel  ...  5 days 00:00:00
# ...

# %%
# В данном случае sharey не указывал, потому, что важнее смотреть отличие от соседних модулей,
# чем относительно других курсов. 
# Если же шкалу выставить одинаковую для всех графиков сильно выделяться будет только UX-дизайн.
fig, ax = fig, ax = plt.subplots(5,3, figsize=(20,25))
# Создаём список курсов. Можно и из исходного датафрейма их вытащить.
titles = df3_1.index.get_level_values(0).unique()
counter = 0

for i in range(5):
    for j in range(3):
# Создаём временный датафрейм для конкретного курса.         
        current_df = df3_1.loc[titles[counter]]['median']
# Реиндексируем временный датафрейм. Дело в том, что по умолчанию plot соединит все точки линиями,
# даже те, где отсутствуют данные. Это может привести к неверной интерпретации графиков.
# Может сложиться впечатление, что медианное время выполнения задания плавно нарастает или убывает,
# хотя это во многих случаях совсем не так.
# Если же значения будут NaN - то plot такие части просто не соединит. Это то, что нам нужно.
        current_df_ri = current_df.reindex(range(current_df.index.astype('int').max()+1))
# Отрисовываем графики для текущего курса. Маркеры выставляем, для того, чтобы было видно те самые 
# "отдельно стоящие" модули. Пунктиром обозначен график без реиндексирования.
# По умолчанию matplotlib timedelta интерпретирует в миллисекундах, поэтому вручную перевожу период в секунды
# и делю на 86400(количество секунд в сутках)
        ax[i,j].plot(current_df.index, current_df.dt.total_seconds()/86400,\
                     ls='--', alpha=0.5, lw=2, marker='o', markersize=7, label='not_reindexed', color='darkorange')
        ax[i,j].plot(current_df_ri.index, current_df_ri.dt.total_seconds()/86400,\
                     lw=2, marker='o', markersize=7, label='reindexed', color='tab:blue')
# Настраиваем оси, подписи, сетку(для лучшей читаемости).
        ax[i,j].set_xticks(current_df_ri.index)
        ax[i,j].tick_params(labelsize=14)
        ax[i,j].set_xlabel('Номер модуля', fontsize=14)
        ax[i,0].set_ylabel('Медианное время\n выполнения работы (дней)', fontsize=14)
        ax[i,j].grid(alpha=0.2)
        ax[i,j].set_title(titles[counter], fontsize=18)
        ax[i,j].legend(fontsize=12)
        counter += 1
# tight_layout увеличит расстояние между axes, таким образом подписи не будут наезжать друг на друга.
# Всё то же самое можно сделать вручную, назначив вертикальное и горизонтальное расстояние между графиками.
plt.tight_layout()
plt.show()

# %%
# 3.3 Здесь насколько я понял нам нужны уже не модули а все домашние работы вообще, поэтому создадим новый датафрейм.

# Сначала почистим датафрейм. Оставим только домашние задания и отбросим те записи,
# где дата начала домашнего задания больше чем дата его окончания. На такие записи потом посмотрим отдельно.
# Чтобы код не загромождать запишем условие фильтрации отдельно.
clause = (main['start_date'] < main['finish_date']) & (main['is_homework']==True)
# Отбросим записи с отсутствующими значениями в столбцах с датами начала и завершения домашней работы.
df3_3 = main[clause].dropna(subset=['start_date', 'finish_date'])
df3_3.finish_date = pd.to_datetime(df3_3.finish_date).dt.tz_localize(None)
df3_3.start_date = pd.to_datetime(df3_3.start_date).dt.tz_localize(None)
# Создадим два столбца, куда запишем только месяцы старта и завершения работы. Для последующей сотрировки
df3_3[['start_month','finish_month']] = df3_3[['start_date','finish_date']].applymap(lambda x: x.month)
# Посчитаем время выполнения домашней работы и запишем в отдельный столбец.
df3_3['homework_time_hours'] = df3_3['finish_date'] - df3_3['start_date']
# Сделаем два варианта, сгруппировав по месяцам начала выполнения домашней работы и по месяцам завершения.
# Сравним как они отличаются на графиках.
df3_3_start = df3_3.groupby(['title','start_month'])['homework_time_hours'].median(numeric_only=None)
df3_3_finish = df3_3.groupby(['title','finish_month'])['homework_time_hours'].median(numeric_only=None)

# %%
# Создадим датафрейм с усредненными значениями и развернём его с помощью unstack
# Таким образом сразу получаем единую шкалу для всех курсов.
df3_3_mean = (df3_3_start+df3_3_finish)/2
df3_3_mean = df3_3_mean.unstack(level= 0)

# Создадим словарь для цветов
# В matplotlib по-умолчанию используется циклическая палитра из 8 цветов, 
# поэтому при 15 графиках цвета будут дублироваться. 
# Чтобы цвета всех графиков были разные я и использую созданный словарь.
colors = sns.color_palette('tab20', 15)
courses = df3_3_mean.columns
color_dict = {}
for color,course in enumerate(courses):
    color_dict[course] = colors[color]

plt.figure(figsize=(20,20))
for title in df3_3_mean.columns:
# По умолчанию matplotlib timedelta интерпретирует в миллисекундах, поэтому вручную перевожу период в секунды
# и делю на 86400(количество секунд в сутках)
    plt.plot(df3_3_mean.index, df3_3_mean[title].dt.total_seconds()/86400, label=title, lw=2, color=color_dict[title])
# Настраиваем оси, подписи, сетку, легенду
plt.xticks(df3_3_mean.index, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Месяцы', fontsize=18)
plt.ylabel('Время выполнения (дней)', fontsize=18)
plt.title('Медианное время выполнения домашней работы по месяцам', fontsize=25)
plt.grid(axis='both', alpha=0.2, ls='--', lw=2)
leg = plt.legend(fontsize=14)
# Линии слишком тонкие в базе, поэтому увеличиваю их толщину в цикле, так лучше читается.
[line.set_linewidth(4) for line in leg.get_lines()]
plt.box(False)
plt.show()

# %% [markdown]
# * По графикам медианного времени выполнения работы по модулям
# для каждого курса заметно, что у подавляющего большинства курсов резко увеличивается время выполнения в последних модулях. Это вполне логично, в последних модулях экзаменационные и дипломные работы, и их выполнение занимает достаточно много времени.
# * Но также по этим графикам можно выявить резкие изменения времени выполнения. И вот по этим "аномальным" изменениям можно выявить проблемные модули.
#
# **Java-разработчик**:
# Пики медианного времени 9 и 12 модулях, между ними резкий спад. Сложность явно сильно отличается.
#
# **SMM-маркетолог от А до Я:**
# Резкий рост после 1 модуля потом столь же резкий спад после 3 модуля и снова резкий подъем после 5 модуля. Очень неравномерный курс.
#
# **UX-дизайн:**
# 9, 11 и 13 модули резко отличаются от всех остальных. Медианное время завершения каждого из них почти в 5 раз превышает время завершения других модулей этого курса.
#
# **Веб-вёрстка для начинающих 2.0:**
# Резкий рост медианного времени в 3 модуле, после чего всё становится более-менее равномерно.
#
# **Веб-дизайн PRO 2.0:**
# Резкий рост медианного времени после 1 модуля и затем скачкообразное уменьшение до последнего - 16 модуля. Довольно странное изменение, к концу курса сложность заданий должна нарастать, как и время на их выполнение. Здесь же ситуация прямо противоположная.
#
# **Интернет-маркетолог от Ingate:**
# Резкие скачки на протяжении всего курса. 2, 3, 6, 8, 12, 15 модули занимают в 2-3 раза больше чем соседние с ними. Неравномерный курс.
#
# **Руководитель digital-проектов:**
# Медианное время прохождения 4 модуля втрое превышает время на 3 и 5 модули. И это единственное такое резкое изменение в этом курсе.
#
# **Предложение: Резкое увеличение времени на завершение модуля может существенно снизить мотивацию студентов. При медианном сроке выполнения работы в 20-60 дней монотонная работа и долговременное отсутствие результата утомляют и демотивируют. Возможно есть смысл разбить такие крупные задачи на части. Поделить на несколько модулей например.**
#
# * Судя по графикам самые стабильные курсы это **JavaScript с нуля, PHP-разработчик с 0 до PRO. Часть 1, Веб-дизайн Базовый, Веб-разработчик**. На этих курсах наблюдается либо равное время прохождения модулей, либо плавное увеличение времени по мере приближения к концу курса.
# * Оценивая сезонные изменения времени выполнения домашней работы по общему графику можно заметить снижение времени в летние месяцы и резкое увеличение времени к сентябрю. Вероятно это связано с двумя факторами: окончание отпусков и начало учебного года. Студенты совмещающие учёбу в ВУЗе или школе с онлайн-курсами соответственно могут тратить гораздо меньше времени на домашние работы. Ну а работающие специалисты большую часть времени посвящают текущей работе.
# * Наибольшее медианное время выполнения домашней работы наблюдается в период с августа по ноябрь у 3 курсов: **Веб-дизайн PRO 2.0, Веб-дизайн Базовый** и **PHP-разработчик с 0 до PRO. Часть 1**

# %% [markdown]
# ## Черновик
# (лучше не смотреть, ибо здесь я только начинал начинать)

# %% [markdown]
# ### 2.1

# %%
# #находим все индексы. в нашем случае это назвы курсов
# titlu = increase.groupby(['title']).nunique().index 
# # titlu = ['Веб-дизайн Базовый']
# #генерируем список, в котором колисество елементов равно длинне количеству названий курсов 
# prirost =[i for i in range(len(titlu))]

# #создаем цикл, в котором задаем некоторые переменные. в цикле проходимся по каждом курсу
# for i,name in enumerate(titlu):
#     year1,month1=2016,4
#     year2,month2=2016,3
#     last_month=0
#     before = 0
#     prirost_titla=[]
    
# # создаем цикл, в котором будем считать прирост за конкретный период конкретного курса
#     while (year1 <=2019) &(last_month<=8):
#         t1=str(year1)+'-'+str(month1)
#         t2=str(year2)+'-'+str(month2)
#         now = increase[(increase.title==name)&(increase.start_date<t1) \
#                  &(increase.start_date>=t2)].student_id.nunique() 
#         month1+=1
#         if month1 ==13:
#             year1+=1
#             month1-=12
#         if year1 ==2019:
#             last_month+=1
            
# #в список количества прироста на даном курсе добавляем разницу между количетсвом людей,
#                         #которые есть на курсе, и которые уже были ранее
#         prirost_titla.append(now-before)
#         if (now-before!=0):
#             before=now

#     #вставляем list(prirost_titla) на одно из значений list(prirost)
#     prirost.insert(i,prirost_titla)
    
#     #удаляем последнее из значений list(prirost), чтобы компенсировать вставку list(prirost_titla)
#     prirost.pop()

# %% [markdown]
# ### 2.2

# %%
# %%time
# first_hw.plot(subplots=True, figsize = (12,8));
# date = []
# year1,month1=2016,2
# year2,month2=2016,1
# last_month=0
# while (year1 <=2019) &(last_month<=6):
#     t1=str(year1)+'-'+str(month1)
#     t2=str(year2)+'-'+str(month2)
#     month1+=1
#     if month1 ==13:
#         year1+=1
#         month1-=12
#     if year1 ==2019:
#         last_month+=1

# #     print(year1,month1)
#     date.append(str(year1)+'-'+str(month1))
# date;

# ##################################
# # 1 способ
# ##################################
# # fig,axs =plt.subplots(nrows=5, ncols=3, figsize = (15,10), sharex = True)
# # row=0
# # col=0
# # for i in range(len(prirost)):
# #     ax = axs[row][col] 
# #     ax.plot(date,prirost[i],label=titlu[i])
# #     ax.legend()
# #     ax.set_title('Прирост студентов')
# #     ax.set_ylabel('Прирост')
# #     col+=1
# #     if col == 3:
# #         row+=1
# #         col-=3
# #     if row==4:
# #         axs[row][col].tick_params(axis='x', rotation=45)


# ##################################
# # 2 способ
# ##################################
# # fig = plt.figure(figsize = (14,14))
# # total_axes = len(prirost)
# # subplt = 1 
# # for i in range(len(prirost)):
# #     ax = fig.add_subplot(total_axes, 1, subplt) 
# #     plt.plot(date,prirost[i],label = spisok_titlow[i]) 
# #     plt.xticks(rotation=60)
# #     plt.legend(loc=2)
# #     subplt+=1

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### 2.3

# %%
# fig = plt.figure(figsize = (12,8))
# for i in range(len(titlu)):
#     plt.plot(date,prirost[i],label=titlu[i])
#     plt.plot(date[np.argmax((prirost[i]))], max(prirost[i]),'s')

# plt.title('Прирост студентов в каждом месяце для каждого курса')
# plt.ylabel("Прирост студентов")
# plt.legend(loc=2)
# plt.box(False)

# plt.xticks(rotation=45)
# plt.show();
